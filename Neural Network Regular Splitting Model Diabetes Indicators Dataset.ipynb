# %% [markdown]
# ## Set-up ##

# %%
# Import packages 
from numpy import loadtxt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
import pandas as pd
import csv
import tensorflow as tf
from keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from scikeras.wrappers import KerasClassifier
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow import keras
import keras_tuner
import datetime

# %% [markdown]
# ## Dataset splitting and defining target and sample data

# %%
# Read in dataset
trn = pd.read_csv("df2.csv", header = 0, na_filter = False)
trn
# Out:
#         Unnamed: 0  Diabetes_binary  HighBP  HighChol  CholCheck  BMI  Smoker  \
# 0                1                0       1         1          1   40       1
# 1                2                0       0         0          0   25       1
# 2                3                0       1         1          1   28       0
# 3                4                0       1         0          1   27       0
# 4                5                0       1         1          1   24       0
# ...            ...              ...     ...       ...        ...  ...     ...
# 253675      253676                0       1         1          1   45       0
# 253676      253677                1       1         1          1   18       0
# 253677      253678                0       0         0          1   28       0
# 253678      253679                0       1         0          1   23       0
# 253679      253680                1       1         1          1   25       0
#
#         Stroke  HeartDiseaseorAttack  PhysActivity  ...  AnyHealthcare  \
# 0            0                     0             0  ...              1
# 1            0                     0             1  ...              0
# 2            0                     0             0  ...              1
# 3            0                     0             1  ...              1
# 4            0                     0             1  ...              1
# ...        ...                   ...           ...  ...            ...
# 253675       0                     0             0  ...              1
# 253676       0                     0             0  ...              1
# 253677       0                     0             1  ...              1
# 253678       0                     0             0  ...              1
# 253679       0                     1             1  ...              1
#
#         NoDocbcCost  GenHlth  MentHlth  PhysHlth  DiffWalk  Sex  Age  \
# 0                 0        5        18        15         1    0    9
# 1                 1        3         0         0         0    0    7
# 2                 1        5        30        30         1    0    9
# 3                 0        2         0         0         0    0   11
# 4                 0        2         3         0         0    0   11
# ...             ...      ...       ...       ...       ...  ...  ...
# 253675            0        3         0         5         0    1    5
# 253676            0        4         0         0         1    0   11
# 253677            0        1         0         0         0    0    2
# 253678            0        3         0         0         0    1    7
# 253679            0        2         0         0         0    0    9
#
#         Education  Income
# 0               4       3
# 1               6       1
# 2               4       8
# 3               3       6
# 4               5       4
# ...           ...     ...
# 253675          6       7
# 253676          2       4
# 253677          5       2
# 253678          5       1
# 253679          6       2
#
# [253680 rows x 23 columns]

# %%
# Check features in dataframe
print(list(trn))
# Out:
# ['Unnamed: 0', 'Diabetes_binary', 'HighBP', 'HighChol', 'CholCheck', 'BMI', 'Smoker', 'Stroke', 'HeartDiseaseorAttack', 'PhysActivity', 'Fruits', 'Veggies', 'HvyAlcoholConsump', 'AnyHealthcare', 'NoDocbcCost', 'GenHlth', 'MentHlth', 'PhysHlth', 'DiffWalk', 'Sex', 'Age', 'Education', 'Income']

# %%
# Drop redundant columns 
trn_new = trn.drop(trn.columns[[0]],
                       axis = 1)

# %%
# View the cleaned dataframe
trn_new.head()
# Out:
#    Diabetes_binary  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0                0       1         1          1   40       1       0
# 1                0       0         0          0   25       1       0
# 2                0       1         1          1   28       0       0
# 3                0       1         0          1   27       0       0
# 4                0       1         1          1   24       0       0
#
#    HeartDiseaseorAttack  PhysActivity  Fruits  ...  AnyHealthcare  \
# 0                     0             0       0  ...              1
# 1                     0             1       0  ...              0
# 2                     0             0       1  ...              1
# 3                     0             1       1  ...              1
# 4                     0             1       1  ...              1
#
#    NoDocbcCost  GenHlth  MentHlth  PhysHlth  DiffWalk  Sex  Age  Education  \
# 0            0        5        18        15         1    0    9          4
# 1            1        3         0         0         0    0    7          6
# 2            1        5        30        30         1    0    9          4
# 3            0        2         0         0         0    0   11          3
# 4            0        2         3         0         0    0   11          5
#
#    Income
# 0       3
# 1       1
# 2       8
# 3       6
# 4       4
#
# [5 rows x 22 columns]

# %%
# Drop the predictor feature from the dataframe
trn_new2 = trn_new.drop(['Diabetes_binary'], axis = 1)

# %%
# View the sample dataframe
trn_new2
# Out:
#         HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0            1         1          1   40       1       0
# 1            0         0          0   25       1       0
# 2            1         1          1   28       0       0
# 3            1         0          1   27       0       0
# 4            1         1          1   24       0       0
# ...        ...       ...        ...  ...     ...     ...
# 253675       1         1          1   45       0       0
# 253676       1         1          1   18       0       0
# 253677       0         0          1   28       0       0
# 253678       1         0          1   23       0       0
# 253679       1         1          1   25       0       0
#
#         HeartDiseaseorAttack  PhysActivity  Fruits  Veggies  ...  \
# 0                          0             0       0        1  ...
# 1                          0             1       0        0  ...
# 2                          0             0       1        0  ...
# 3                          0             1       1        1  ...
# 4                          0             1       1        1  ...
# ...                      ...           ...     ...      ...  ...
# 253675                     0             0       1        1  ...
# 253676                     0             0       0        0  ...
# 253677                     0             1       1        0  ...
# 253678                     0             0       1        1  ...
# 253679                     1             1       1        0  ...
#
#         AnyHealthcare  NoDocbcCost  GenHlth  MentHlth  PhysHlth  DiffWalk  \
# 0                   1            0        5        18        15         1
# 1                   0            1        3         0         0         0
# 2                   1            1        5        30        30         1
# 3                   1            0        2         0         0         0
# 4                   1            0        2         3         0         0
# ...               ...          ...      ...       ...       ...       ...
# 253675              1            0        3         0         5         0
# 253676              1            0        4         0         0         1
# 253677              1            0        1         0         0         0
# 253678              1            0        3         0         0         0
# 253679              1            0        2         0         0         0
#
#         Sex  Age  Education  Income
# 0         0    9          4       3
# 1         0    7          6       1
# 2         0    9          4       8
# 3         0   11          3       6
# 4         0   11          5       4
# ...     ...  ...        ...     ...
# 253675    1    5          6       7
# 253676    0   11          2       4
# 253677    0    2          5       2
# 253678    1    7          5       1
# 253679    0    9          6       2
#
# [253680 rows x 21 columns]

# %%
# Sort the predictor variable
y = trn_new['Diabetes_binary']

# %%
# View the dataframe
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 253675    0
# 253676    1
# 253677    0
# 253678    0
# 253679    1
# Name: Diabetes_binary, Length: 253680, dtype: int64

# %% [markdown]
# ## Early Stopping ##

# %%
# Creating early stopping
custom_early_stopping = EarlyStopping(
    monitor='val_accuracy', 
    patience=20, 
    min_delta=0.001, 
    mode='max'
)

# %% [markdown]
# ## Static model ##

# %%
# Define the keras model
model = Sequential()
model.add(Input(shape=(21,)))
model.add(Dense(21, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# Compiling the model
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
# Converting dataframes to tensor
trn_new2 = tf.convert_to_tensor(trn_new2)
y = tf.convert_to_tensor(y)

# %%
# Fit the keras model on the dataset
model.fit(trn_new2, y, epochs=1500, batch_size=500, callbacks = [custom_early_stopping], validation_split=0.2)
# Out:
# Epoch 1/1500
# 406/406 [==============================] - 1s 2ms/step - loss: 0.3764 - accuracy: 0.8576 - val_loss: 0.3403 - val_accuracy: 0.8597
# Epoch 2/1500
# 406/406 [==============================] - 1s 2ms/step - loss: 0.3321 - accuracy: 0.8623 - val_loss: 0.3312 - val_accuracy: 0.8602
# Epoch 3/1500
# 406/406 [==============================] - 1s 2ms/step - loss: 0.3269 - accuracy: 0.8633 - val_loss: 0.3277 - val_accuracy: 0.8611
# Epoch 4/1500
# 406/406 [==============================] - 1s 2ms/step - loss: 0.3245 - accuracy: 0.8641 - val_loss: 0.3256 - val_accuracy: 0.8618
# Epoch 5/1500
# 406/406 [==============================] - 1s 2ms/step - loss: 0.3227 - accuracy: 0.8648 - val_loss: 0.3278 - val_accuracy: 0.8595
# Epoch 6/1500
# 406/406 [==============================] - 1s 2ms/step - loss: 0.3212 - accuracy: 0.8647 - val_loss: 0.3236 - val_accuracy: 0.8623
# Epoch 7/1500
# 406/406 [==============================] - 1s 2ms/step - loss: 0.3200 - accuracy: 0.8655 - val_loss: 0.3218 - val_accuracy: 0.8617
# Epoch 8/1500
# 406/406 [==============================] - 1s 2ms/step - loss: 0.3194 - accuracy: 0.8654 - val_loss: 0.3209 - val_accuracy: 0.8629
# Epoch 9/1500
# 406/406 [==============================] - 1s 2ms/step - loss: 0.3186 - accuracy: 0.8657 - val_loss: 0.3198 - val_accuracy: 0.8629
# Epoch 10/1500
# 406/406 [==============================] - 1s 2ms/step - loss: 0.3180 - accuracy: 0.8660 - val_loss: 0.3197 - val_accuracy: 0.8636
# Epoch 11/1500
# 406/406 [==============================] - 1s 2ms/step - loss: 0.3174 - accuracy: 0.8663 - val_loss: 0.3215 - val_accuracy: 0.8624
# Epoch 12/1500
# 406/406 [==============================] - 1s 2ms/step - loss: 0.3169 - accuracy: 0.8662 - val_loss: 0.3192 - val_accuracy: 0.8633
# Epoch 13/1500
# 406/406 [==============================] - 1s 2ms/step - loss: 0.3163 - accuracy: 0.8664 - val_loss: 0.3181 - val_accuracy: 0.8634
# Epoch 14/1500
# 406/406 [==============================] - 1s 2ms/step - loss: 0.3160 - accuracy: 0.8663 - val_loss: 0.3176 - val_accuracy: 0.8639
# Epoch 15/1500
# 406/406 [==============================] - 1s 2ms/step - loss: 0.3159 - accuracy: 0.8666 - val_loss: 0.3195 - val_accuracy: 0.8630
# Epoch 16/1500
# 406/406 [==============================] - 1s 2ms/step - loss: 0.3153 - accuracy: 0.8667 - val_loss: 0.3188 - val_accuracy: 0.8625
# Epoch 17/1500
# 406/406 [==============================] - 1s 2ms/step - loss: 0.3153 - accuracy: 0.8669 - val_loss: 0.3177 - val_accuracy: 0.8640
# Epoch 18/1500
# 406/406 [==============================] - 1s 2ms/step - loss: 0.3149 - accuracy: 0.8666 - val_loss: 0.3175 - val_accuracy: 0.8636
# Epoch 19/1500
# 406/406 [==============================] - 1s 2ms/step - loss: 0.3151 - accuracy: 0.8666 - val_loss: 0.3173 - val_accuracy: 0.8641
# Epoch 20/1500
# 406/406 [==============================] - 1s 2ms/step - loss: 0.3150 - accuracy: 0.8669 - val_loss: 0.3163 - val_accuracy: 0.8640
# Epoch 21/1500
# 406/406 [==============================] - 1s 2ms/step - loss: 0.3147 - accuracy: 0.8664 - val_loss: 0.3166 - val_accuracy: 0.8639
# Epoch 22/1500
# 406/406 [==============================] - 1s 2ms/step - loss: 0.3146 - accuracy: 0.8665 - val_loss: 0.3159 - val_accuracy: 0.8642
# Epoch 23/1500
# 406/406 [==============================] - 1s 2ms/step - loss: 0.3143 - accuracy: 0.8668 - val_loss: 0.3165 - val_accuracy: 0.8636
# Epoch 24/1500
# 406/406 [==============================] - 1s 2ms/step - loss: 0.3144 - accuracy: 0.8668 - val_loss: 0.3161 - val_accuracy: 0.8638
# Epoch 25/1500
# 406/406 [==============================] - 1s 2ms/step - loss: 0.3139 - accuracy: 0.8665 - val_loss: 0.3159 - val_accuracy: 0.8641
# Epoch 26/1500
# 406/406 [==============================] - 1s 2ms/step - loss: 0.3140 - accuracy: 0.8667 - val_loss: 0.3155 - val_accuracy: 0.8644
# Epoch 27/1500
# 406/406 [==============================] - 1s 3ms/step - loss: 0.3135 - accuracy: 0.8669 - val_loss: 0.3161 - val_accuracy: 0.8638
# Epoch 28/1500
# 406/406 [==============================] - 1s 3ms/step - loss: 0.3137 - accuracy: 0.8668 - val_loss: 0.3165 - val_accuracy: 0.8642
# Epoch 29/1500
# 406/406 [==============================] - 1s 3ms/step - loss: 0.3137 - accuracy: 0.8667 - val_loss: 0.3164 - val_accuracy: 0.8637
# Epoch 30/1500
# 406/406 [==============================] - 1s 3ms/step - loss: 0.3136 - accuracy: 0.8665 - val_loss: 0.3187 - val_accuracy: 0.8630

# %% [markdown]
# ## Model function ##

# %%
# Creating model function
def get_model(hp):
    model = Sequential()
    model.add(Input(shape=(21,)))
    for i in range(hp.Int("num_layers",1,7)):
        model.add(Dense(units = hp.Int(f"units_{i}",min_value = 10, max_value = 28, step = 3), activation = hp.Choice("activation",["relu","tanh"]),))
    model.add(Dense(1, activation='sigmoid'))
    learning_rate = hp.Float("lr",min_value = 1e-4,max_value = 1e-2,sampling="log")
    model.compile(loss = 'binary_crossentropy', optimizer = tf.keras.optimizers.Adam(learning_rate = learning_rate), metrics = ['accuracy'])
    return model

# %% [markdown]
# ## Tensorboard

# %%
# Setting tensorboard callback
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir="./logs")

# %% [markdown]
# ## Keras Tuner

# %%
# Defining Keras tuner
tuner = keras_tuner.RandomSearch(hypermodel=get_model,objective="val_accuracy",max_trials=30,executions_per_trial=1,overwrite=True,directory="./benmk/",project_name="diabetes")

# %%
# Whats being captured by the Keras tuner
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 4
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 7, 'step': 1, 'sampling': 'linear'}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 10, 'max_value': 28, 'step': 3, 'sampling': 'linear'}
# activation (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'tanh'], 'ordered': False}
# lr (Float)
# {'default': 0.0001, 'conditions': [], 'min_value': 0.0001, 'max_value': 0.01, 'step': None, 'sampling': 'log'}

# %%
# Fit the keras model on the dataset
tuner.search(trn_new2, y, epochs=1500, batch_size=500, 
             callbacks = [custom_early_stopping, tensorboard_callback], validation_split=0.2)
# Out:
# Trial 30 Complete [00h 00m 42s]
# val_accuracy: 0.8649479746818542
#
# Best val_accuracy So Far: 0.8654603958129883
# Total elapsed time: 00h 20m 50s
# INFO:tensorflow:Oracle triggered exit

# %% [markdown]
# ## Tensorboard

# %%
# Load the extension for tensorboard
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
# Reload extension for tensorboard
# %reload_ext tensorboard

# %%
# Launch tensorboard
# %tensorboard --logdir "./logs"
# Out:
# Reusing TensorBoard on port 6006 (pid 1108), started 3 days, 16:35:42 ago. (Use '!kill 1108' to kill it.)
#       <iframe id="tensorboard-frame-fe11e47c9314bd19" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-fe11e47c9314bd19");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# Launch tensorboard alternative way
# %tensorboard --logdir "./logs"  --host localhost
# Out:
# Reusing TensorBoard on port 6006 (pid 8548), started 22:12:07 ago. (Use '!kill 8548' to kill it.)
#       <iframe id="tensorboard-frame-c9d7e8418f3f92bd" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-c9d7e8418f3f92bd");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
